# %%
print("==SOAL NO 1==")
print("")
dadu = 6
k1 = 3
jml = k1 / dadu
print("Probabilitas percobaan 1 : "+ str(jml))

k2 = 2
jml2 = k2 / dadu
print("Probabilitas percobaan 2 : "+ str(jml2))

k3 = 4
jml3 = k3 / dadu
print("Probabilitas percobaan 3 : "+ str(jml3))

k4 = 5
jml4 = k4 / dadu
print("Probabilitas percobaan 4 : "+ str(jml4))

k5 = 6
jml5 = k5 / dadu
print("Probabilitas percobaan 5 : "+ str(jml5))

k6 = 1
jml6 = k6 / dadu
print("Probabilitas percobaan 6 : "+ str(jml6))

k7 = 5
jml7 = k7 / dadu
print("Probabilitas percobaan 7 : "+ str(jml7))

k8 = 6
jml8 = k8 / dadu
print("Probabilitas percobaan 8 : "+ str(jml8))

k9 = 3
jml9 = k9 / dadu
print("Probabilitas percobaan 9 : "+ str(jml9))

k10 = 2
jml10 = k10 / dadu
print("Probabilitas percobaan 10 : "+ str(jml10))

k11 = 2
jml11 = k11 / dadu
print("Probabilitas percobaan 11 : "+ str(jml11))

k12 = 1
jml12 = k12 / dadu
print("Probabilitas percobaan 12 : "+ str(jml12))

k13 = 3
jml13 = k13 / dadu
print("Probabilitas percobaan 13 : "+ str(jml13))

k14 = 1
jml14 = k14 / dadu
print("Probabilitas percobaan 14 : "+ str(jml14))

k15 = 5
jml15 = k15 / dadu
print("Probabilitas percobaan 15 : "+ str(jml15))

print("================================================")
jmlh = jml + jml2 + jml3 + jml4 + jml5 + jml6 + jml7 + jml8 + jml9 + jml10 + jml11 + jml12 + jml13 + jml14 + jml15
print("Total Jumlah nilai probabilitas setiap percobaan : "+str(jmlh))

print("================================================")
k1 = 3 / 4
print("Probabilitas percobaan : "+ str(k1))
k2 = 4 / 4
print("Probabilitas percobaan : "+ str(k2))
k3 = 1 / 4
print("Probabilitas percobaan : "+ str(k3))
k4 = 3 / 4
print("Probabilitas percobaan : "+ str(k4))
k5 = 2 / 4
print("Probabilitas percobaan : "+ str(k5))
k6 = 2 / 4
print("Probabilitas percobaan : "+ str(k6))
k7 = 1 / 4
print("Probabilitas percobaan : "+ str(k7))
k8 = 3 / 4
print("Probabilitas percobaan : "+ str(k8))
k9 = 1 / 4
print("Probabilitas percobaan : "+ str(k9))
jmlh2 = k1 + k2 + k3 + k4 + k5 + k6 + k7 + k8 + k9
print("Jumlah keluaran yang keluar nilai < 5 : "+str(jmlh2))

print("================================================")
pro1 = 9 / 12
print("Probabilitas percobaan 1 : "+str(pro1))
pro2 = 11 / 12
print("Probabilitas percobaan 2 : "+str(pro2))
pro3 = 3 / 12
print("Probabilitas percobaan 3 : "+str(pro3))
pro4 = 6 / 12
print("Probabilitas percobaan 4 : "+str(pro4))
pro5 = 2 /12
print("Probabilitas percobaan 5 : "+str(pro5))
pro6 = 4 / 12
print("Probabilitas percobaan 6 : "+str(pro6))
pro7 = 9 / 12
print("Probabilitas percobaan 7 : "+str(pro7))
pro8 = 12 / 12
print("Probabilitas percobaan 8 : "+str(pro8))
pro9 = 10 / 12
print("Probabilitas percobaan 9 : "+str(pro9))
pro10 = 8 / 12
print("Probabilitas percobaan 10 : "+str(pro10))
pro11 = 2 / 12
print("Probabilitas percobaan 11 : "+str(pro11))
pro12 = 6 / 12
print("Probabilitas percobaan 12 : "+str(pro12))
pro13 = 3 / 12
print("Probabilitas percobaan 13 : "+str(pro13))
pro14 = 4 / 12
print("Probabilitas percobaan 14 : "+str(pro14))
pro15 = 9 / 12
print("Probabilitas percobaan 15 : "+str(pro15))
pro16 = 8 / 12
print("Probabilitas percobaan 16 : "+str(pro16))
pro17 = 5 / 12
print("Probabilitas percobaan 17 : "+str(pro17))
pro18 = 6 / 12
print("Probabilitas percobaan 18 : "+str(pro18))
pro19 = 11 / 12
print("Probabilitas percobaan 19 : "+str(pro19))
pro20 = 10 / 12
print("Probabilitas percobaan 20 : "+str(pro20))
print("")
jmlhpro = pro1 + pro2 + pro3 + pro4 + pro5 + pro6 + pro7 + pro8 + pro9 + pro10 + pro11 + pro12 + pro13 + pro14 + pro15 + pro16 + pro17 + pro18 + pro19 + pro20
print("Total Jumlah nilai probabilitas setiap percobaan : "+str(jmlhpro))
print("")
print("==============================================")
k1 = 6 / 6
print("Probabilitas percobaan 1 : "+ str(k1))
k2 = 2 / 6
print("Probabilitas percobaan 2 : "+ str(k2))
k3 = 4 / 6
print("Probabilitas percobaan 3 : "+ str(k3))
k4 = 12 / 6
print("Probabilitas percobaan 4 : "+ str(k4))
k5 = 10 / 6
print("Probabilitas percobaan 5 : "+ str(k5))
k6 = 8 / 6
print("Probabilitas percobaan 6 : "+ str(k6))
k7 = 2 / 6
print("Probabilitas percobaan 7 : "+ str(k7))
k8 = 6 / 6
print("Probabilitas percobaan 8 : "+ str(k8))
k9 = 4 / 6
print("Probabilitas percobaan 9 : "+ str(k9))
k10 = 8 / 6
print("Probabilitas percobaan 10 : "+ str(k10))
k11 = 6 / 6
print("Probabilitas percobaan 11 : "+ str(k11))
k12 = 10 / 6
print("Probabilitas percobaan 12 : "+ str(k12))
jmlh = k1 + k2 + k3 + k4 + k5 + k6 + k7 + k8 + k9 + k10 + k11 + k12
print("Total Pelamparan dadu yang memiliki nilai genap : "+ str(k4))
# Out:
# ==SOAL NO 1==
#
# Probabilitas percobaan 1 : 0.5
# Probabilitas percobaan 2 : 0.3333333333333333
# Probabilitas percobaan 3 : 0.6666666666666666
# Probabilitas percobaan 4 : 0.8333333333333334
# Probabilitas percobaan 5 : 1.0
# Probabilitas percobaan 6 : 0.16666666666666666
# Probabilitas percobaan 7 : 0.8333333333333334
# Probabilitas percobaan 8 : 1.0
# Probabilitas percobaan 9 : 0.5
# Probabilitas percobaan 10 : 0.3333333333333333
# Probabilitas percobaan 11 : 0.3333333333333333
# Probabilitas percobaan 12 : 0.16666666666666666
# Probabilitas percobaan 13 : 0.5
# Probabilitas percobaan 14 : 0.16666666666666666
# Probabilitas percobaan 15 : 0.8333333333333334
# ...
# Total Jumlah nilai probabilitas setiap percobaan : 8.166666666666666
# ...
# Probabilitas percobaan : 0.75
# Probabilitas percobaan : 1.0
# Probabilitas percobaan : 0.25
# Probabilitas percobaan : 0.75
# Probabilitas percobaan : 0.5
# Probabilitas percobaan : 0.5
# Probabilitas percobaan : 0.25
# Probabilitas percobaan : 0.75
# ...

# %%
import matplotlib.pyplot as plt

print("Soal 2")
print("No 1")
minggu1 = 6560860 + 5950850 + 12685900 + 5768500 + 2989000 
print("Jumlah Pendapatan Minggu 1 : "+str(minggu1))

minggu2 = 8782150 + 6620000 + 5128750 + 5217300 + 4820600
print("Jumlah Pendapatan Minggu 2 : "+str(minggu2))

minggu3 = 8130940 + 2940650 + 3488200 + 6930540 + 4319260
print("Jumlah Pendapatan Minggu 3 : "+str(minggu3))

minggu4 = 12849100 + 5752200 + 5128400 + 3880490 + 4982100
print("Jumlah Pendapatan Minggu 4 : "+str(minggu4))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['Minggu 1','Minggu 2', 'Minggu 3','Minggu 4']
jumlah = [33955110, 30568800, 25809590,32592290]
c = ['red','blue', 'green', 'yellow']
plt.title("Grafik Pendapatan Per minggu")
ax.bar(eskul,jumlah,color = c )
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ['Minggu 1','Minggu 2', 'Minggu 3','Minggu 4']
jumlah = [33955110, 30568800, 25809590,32592290]
ax.pie(jumlah,labels=eskul,autopct="%1.2f%%")
plt.title("Grafik Piechart Pendapatan Per minggu")
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['Minggu 1','Minggu 2', 'Minggu 3','Minggu 4']
jumlah = [33955110, 30568800, 25809590,32592290]
c = ['red','blue', 'green', 'yellow']
plt.title("Grafik Pendapatan Per minggu")
ax.scatter(eskul,jumlah,color = c )
plt.show()
# Out:
# Soal 2
# No 1
# Jumlah Pendapatan Minggu 1 : 33955110
# Jumlah Pendapatan Minggu 2 : 30568800
# Jumlah Pendapatan Minggu 3 : 25809590
# Jumlah Pendapatan Minggu 4 : 32592290

# %%
print("No 2")
minggu1 = (386 + 752 + 1203 + 715 + 289) / 5 
print("Jumlah Produk terjual Minggu 1 : "+str(minggu1))

minggu2 = (454 + 781 + 634 + 659 + 411) / 5
print("Jumlah Produk terjual Minggu 2 : "+str(minggu2))

minggu3 = (599 + 338 + 442 + 872 + 390) / 5
print("Jumlah Produk terjual Minggu 3 : "+str(minggu3))

minggu4 = (867 + 512 + 650 + 492 + 488) / 5
print("Jumlah Produk terjual Minggu 4 : "+str(minggu4))
# Out:
# No 2
# Jumlah Produk terjual Minggu 1 : 669.0
# Jumlah Produk terjual Minggu 2 : 587.8
# Jumlah Produk terjual Minggu 3 : 528.2
# Jumlah Produk terjual Minggu 4 : 601.8

# %%
print("No 3")
minggu1 = 180 + 164 + 218 + 156 + 92
print("Jumlah Pengunjung Minggu 1 : "+str(minggu1))
senin = minggu1 / 10
print("Pengunjung Hari Senin : "+str(senin))
selasa = minggu1 / 10
print("Pengunjung Hari Selasa : "+str(selasa))
rabu = minggu1 / 10
print("Pengunjung Hari Rabu : "+str(rabu))
kamis = minggu1 / 10
print("Pengunjung Hari Kamis : "+str(kamis))
jumat = minggu1 / 10
print("Pengunjung Hari Jumat : "+str(jumat))
print("============")
jmlh1 = minggu1 - (senin + selasa + rabu + kamis + jumat)
print("Senin sd jumat : "+str(jmlh1))
print("============")
sabtu = jmlh1 / 2 
print("Pengunjung Hari Sabtu : "+str(sabtu))
minggu = jmlh1 / 2
print("Pengunjung Hari Minggu : "+str(minggu))
print("============")
jmlh = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("jumlah : "+str(jmlh))

print("")
minggu1 = 156 + 212 + 164 + 144 + 138
print("Jumlah Pengunjung Minggu 2 : "+str(minggu1))
senin = minggu1 / 10
print("Pengunjung Hari Senin : "+str(senin))
selasa = minggu1 / 10
print("Pengunjung Hari Selasa : "+str(selasa))
rabu = minggu1 / 10
print("Pengunjung Hari Rabu : "+str(rabu))
kamis = minggu1 / 10
print("Pengunjung Hari Kamis : "+str(kamis))
jumat = minggu1 / 10
print("Pengunjung Hari Jumat : "+str(jumat))
print("============")
jmlh1 = minggu1 - (senin + selasa + rabu + kamis + jumat)
print("Senin sd jumat : "+str(jmlh1))
print("============")
sabtu = jmlh1 / 2 
print("Pengunjung Hari Sabtu : "+str(sabtu))
minggu = jmlh1 / 2
print("Pengunjung Hari Minggu : "+str(minggu))
print("============")
jmlh = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("jumlah : "+str(jmlh))

print("")
minggu1 = 290 + 95 + 120 + 225 + 135
print("Jumlah Pengunjung Minggu 3 : "+str(minggu1))
senin = minggu1 / 10
print("Pengunjung Hari Senin : "+str(senin))
selasa = minggu1 / 10
print("Pengunjung Hari Selasa : "+str(selasa))
rabu = minggu1 / 10
print("Pengunjung Hari Rabu : "+str(rabu))
kamis = minggu1 / 10
print("Pengunjung Hari Kamis : "+str(kamis))
jumat = minggu1 / 10
print("Pengunjung Hari Jumat : "+str(jumat))
print("============")
jmlh1 = minggu1 - (senin + selasa + rabu + kamis + jumat)
print("Senin sd jumat : "+str(jmlh1))
print("============")
sabtu = jmlh1 / 2 
print("Pengunjung Hari Sabtu : "+str(sabtu))
minggu = jmlh1 / 2
print("Pengunjung Hari Minggu : "+str(minggu))
print("============")
jmlh = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("jumlah : "+str(jmlh))

print("")
minggu1 = 350 + 143 + 201 + 174 + 205
print("Jumlah Pengunjung Minggu 4 : "+str(minggu1))
senin = minggu1 / 10
print("Pengunjung Hari Senin : "+str(senin))
selasa = minggu1 / 10
print("Pengunjung Hari Selasa : "+str(selasa))
rabu = minggu1 / 10
print("Pengunjung Hari Rabu : "+str(rabu))
kamis = minggu1 / 10
print("Pengunjung Hari Kamis : "+str(kamis))
jumat = minggu1 / 10
print("Pengunjung Hari Jumat : "+str(jumat))
print("============")
jmlh1 = minggu1 - (senin + selasa + rabu + kamis + jumat)
print("Senin sd jumat : "+str(jmlh1))
print("============")
sabtu = jmlh1 / 2 
print("Pengunjung Hari Sabtu : "+str(sabtu))
minggu = jmlh1 / 2
print("Pengunjung Hari Minggu : "+str(minggu))
print("============")
jmlh = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("jumlah : "+str(jmlh))
# Out:
# No 3
# Jumlah Pengunjung Minggu 1 : 810
# Pengunjung Hari Senin : 81.0
# Pengunjung Hari Selasa : 81.0
# Pengunjung Hari Rabu : 81.0
# Pengunjung Hari Kamis : 81.0
# Pengunjung Hari Jumat : 81.0
# ...
# Senin sd jumat : 405.0
# ...
# Pengunjung Hari Sabtu : 202.5
# Pengunjung Hari Minggu : 202.5
# ...
# jumlah : 810.0
#
# Jumlah Pengunjung Minggu 2 : 814
# Pengunjung Hari Senin : 81.4
# Pengunjung Hari Selasa : 81.4
# Pengunjung Hari Rabu : 81.4
# Pengunjung Hari Kamis : 81.4
# Pengunjung Hari Jumat : 81.4
# ...
# Senin sd jumat : 407.0
# ...
# Pengunjung Hari Sabtu : 203.5
# Pengunjung Hari Minggu : 203.5
# ...
# jumlah : 814.0
#
# Jumlah Pengunjung Minggu 3 : 865
# Pengunjung Hari Senin : 86.5
# Pengunjung Hari Selasa : 86.5
# Pengunjung Hari Rabu : 86.5
# Pengunjung Hari Kamis : 86.5
# Pengunjung Hari Jumat : 86.5
# ...
# Senin sd jumat : 432.5
# ...
# Pengunjung Hari Sabtu : 216.25
# Pengunjung Hari Minggu : 216.25
# ...
# jumlah : 865.0
#
# Jumlah Pengunjung Minggu 4 : 1073
# Pengunjung Hari Senin : 107.3
# ...

# %%
print("No 4")
minggu1 = 6560860 + 5950850 + 12685900 + 5768500 + 2989000
print("Jumlah Omzet Minggu 1 : "+str(minggu1))
senin = minggu1 / 10
print("Omzet Hari Senin : "+str(senin))
selasa = minggu1 / 10
print("Omzet Hari Selasa : "+str(selasa))
rabu = minggu1 / 10
print("Omzet Hari Rabu : "+str(rabu))
kamis = minggu1 / 10
print("Omzet Hari Kamis : "+str(kamis))
jumat = minggu1 / 10
print("Omzet Hari Jumat : "+str(jumat))
print("============")
jmlh1 = minggu1 - (senin + selasa + rabu + kamis + jumat)
print("Senin sd jumat : "+str(jmlh1))
print("============")
sabtu = jmlh1 / 2 
print("Omzet Hari Sabtu : "+str(sabtu))
minggu = jmlh1 / 2
print("Omzet Hari Minggu : "+str(minggu))
print("============")
jmlh = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("jumlah : "+str(jmlh))

print("")
minggu1 = 8782150 + 6620000 + 5128750 + 5217300 + 4820600
print("Jumlah Omzet Minggu 2 : "+str(minggu1))
senin = minggu1 / 10
print("Omzet Hari Senin : "+str(senin))
selasa = minggu1 / 10
print("Omzet Hari Selasa : "+str(selasa))
rabu = minggu1 / 10
print("Omzet Hari Rabu : "+str(rabu))
kamis = minggu1 / 10
print("Omzet Hari Kamis : "+str(kamis))
jumat = minggu1 / 10
print("Omzet Hari Jumat : "+str(jumat))
print("============")
jmlh1 = minggu1 - (senin + selasa + rabu + kamis + jumat)
print("Senin sd jumat : "+str(jmlh1))
print("============")
sabtu = jmlh1 / 2 
print("Omzet Hari Sabtu : "+str(sabtu))
minggu = jmlh1 / 2
print("Omzet Hari Minggu : "+str(minggu))
print("============")
jmlh = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("jumlah : "+str(jmlh))

print("")
minggu1 = 8130940 + 2940650 + 3488200 + 6930540 + 4319260
print("Jumlah Omzet Minggu 3 : "+str(minggu1))
senin = minggu1 / 10
print("Omzet Hari Senin : "+str(senin))
selasa = minggu1 / 10
print("Omzet Hari Selasa : "+str(selasa))
rabu = minggu1 / 10
print("Omzet Hari Rabu : "+str(rabu))
kamis = minggu1 / 10
print("Omzet Hari Kamis : "+str(kamis))
jumat = minggu1 / 10
print("Omzet Hari Jumat : "+str(jumat))
print("============")
jmlh1 = minggu1 - (senin + selasa + rabu + kamis + jumat)
print("Senin sd jumat : "+str(jmlh1))
print("============")
sabtu = jmlh1 / 2 
print("Omzet Hari Sabtu : "+str(sabtu))
minggu = jmlh1 / 2
print("Omzet Hari Minggu : "+str(minggu))
print("============")
jmlh = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("jumlah : "+str(jmlh))

print("")
minggu1 = 12849100 + 5752200 + 5128400 + 3880490 + 4982100
print("Jumlah Omzet Minggu 4 : "+str(minggu1))
senin = minggu1 / 10
print("Omzet Hari Senin : "+str(senin))
selasa = minggu1 / 10
print("Omzet Hari Selasa : "+str(selasa))
rabu = minggu1 / 10
print("Omzet Hari Rabu : "+str(rabu))
kamis = minggu1 / 10
print("Omzet Hari Kamis : "+str(kamis))
jumat = minggu1 / 10
print("Omzet Hari Jumat : "+str(jumat))
print("============")
jmlh1 = minggu1 - (senin + selasa + rabu + kamis + jumat)
print("Senin sd jumat : "+str(jmlh1))
print("============")
sabtu = jmlh1 / 2 
print("Omzet Hari Sabtu : "+str(sabtu))
minggu = jmlh1 / 2
print("Omzet Hari Minggu : "+str(minggu))
print("============")
jmlh = senin + selasa + rabu + kamis + jumat + sabtu + minggu
print("jumlah : "+str(jmlh))
# Out:
# No 4
# Jumlah Omzet Minggu 1 : 33955110
# Omzet Hari Senin : 3395511.0
# Omzet Hari Selasa : 3395511.0
# Omzet Hari Rabu : 3395511.0
# Omzet Hari Kamis : 3395511.0
# Omzet Hari Jumat : 3395511.0
# ...
# Senin sd jumat : 16977555.0
# ...
# Omzet Hari Sabtu : 8488777.5
# Omzet Hari Minggu : 8488777.5
# ...
# jumlah : 33955110.0
#
# Jumlah Omzet Minggu 2 : 30568800
# Omzet Hari Senin : 3056880.0
# Omzet Hari Selasa : 3056880.0
# Omzet Hari Rabu : 3056880.0
# Omzet Hari Kamis : 3056880.0
# Omzet Hari Jumat : 3056880.0
# ...
# Senin sd jumat : 15284400.0
# ...
# Omzet Hari Sabtu : 7642200.0
# Omzet Hari Minggu : 7642200.0
# ...
# jumlah : 30568800.0
#
# Jumlah Omzet Minggu 3 : 25809590
# Omzet Hari Senin : 2580959.0
# Omzet Hari Selasa : 2580959.0
# Omzet Hari Rabu : 2580959.0
# Omzet Hari Kamis : 2580959.0
# Omzet Hari Jumat : 2580959.0
# ...
# Senin sd jumat : 12904795.0
# ...
# Omzet Hari Sabtu : 6452397.5
# Omzet Hari Minggu : 6452397.5
# ...
# jumlah : 25809590.0
#
# Jumlah Omzet Minggu 4 : 32592290
# Omzet Hari Senin : 3259229.0
# ...

# %%
jmlh = 386 + 752 + 1203 + 715 + 289 + 454 + 781 + 634 + 659 + 411 + 599 + 338 + 442 + 872 + 390 + 867 + 512 + 650 + 492 + 488
print("Jumlah Penjualan produk : "+str(jmlh))

jmlh2 = 6560860 + 5950850 + 12685900 + 5768500 + 2989000 + 8782150 + 6620000 + 5128750 + 5217300 + 4820600 + 8130940 + 2940650 + 3488200 + 6930540 + 4319260 + 12849100 + 5752200 + 5128400 + 3880490 + 4982100
print("Jumlah Pendapatan : "+str(jmlh2))

jmlh1 = jmlh + jmlh2
print("Jumlah penjualan produk + pendapatan : "+str(jmlh1))
# Out:
# Jumlah Penjualan produk : 11934
# Jumlah Pendapatan : 122925790
# Jumlah penjualan produk + pendapatan : 122937724
